# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data_path = '/data1/practical-sose23/castellvi/team_repo/3D-Castellvi-Prediction/experiments/baseline_models/densenet/eval_results_verse.json'
df_gt = '/data1/practical-sose23/castellvi/team_repo/3D-Castellvi-Prediction/src/dataset/Castellvi_list_v2.xlsx'
df_gt = pd.read_excel(df_gt)
# Load the data
with open(data_path, 'r') as f:
    data = json.load(f)

# Transform the data into a DataFrame
df = pd.json_normalize(data)

# %%
df
# Out:
#    subject_name actual actual_R actual_flip_R  correct pred.experiment_5  \
# 0      verse005      0        0             0      3.0                 0
# 1      verse015     2a        0             2      NaN                 0
# 2      verse016      0        0             0      3.0                 0
# 3      verse022      0        0             0      3.0                 0
# 4      verse030      0        0             0      3.0                 0
# ..          ...    ...      ...           ...      ...               ...
# 73     verse808     2a        2             0      3.0                2a
# 74     verse810      0        0             0      3.0                 0
# 75     verse817      0        0             0      3.0                 0
# 76     verse826      0        0             0      3.0                 0
# 77     verse835      0        0             0      3.0                 0
#
#    pred.experiment_9 pred.experiment_10 pred_R.experiment_5  \
# ...

# %%
# fill the NaN values with 0
df = df.fillna(0)

# %%
df
# Out:
#    subject_name actual actual_R actual_flip_R  correct pred.experiment_5  \
# 0      verse005      0        0             0      3.0                 0
# 1      verse015     2a        0             2      0.0                 0
# 2      verse016      0        0             0      3.0                 0
# 3      verse022      0        0             0      3.0                 0
# 4      verse030      0        0             0      3.0                 0
# ..          ...    ...      ...           ...      ...               ...
# 73     verse808     2a        2             0      3.0                2a
# 74     verse810      0        0             0      3.0                 0
# 75     verse817      0        0             0      3.0                 0
# 76     verse826      0        0             0      3.0                 0
# 77     verse835      0        0             0      3.0                 0
#
#    pred.experiment_9 pred.experiment_10 pred_R.experiment_5  \
# ...

# %%
# sort descending by the incorrect column
df = df.sort_values(by=['incorrect'], ascending=False)

# %%
df.reset_index(drop=True, inplace=True)

# %%
# display all rows in pandas
pd.set_option('display.max_rows', None)
df
# Out:
#    subject_name actual actual_R actual_flip_R  correct pred.experiment_5  \
# 0      verse542     2b        2             2      0.0                2a
# 1      verse015     2a        0             2      0.0                 0
# 2      verse526     3b        3             3      0.0                3a
# 3      verse607     2a        0             2      1.0                 0
# 4      verse085     3a        3             0      1.0                3a
# 5      verse594     3b        3             3      1.0                 0
# 6      verse765      0        0             0      1.0                 0
# 7      verse540     2a        2             0      2.0                2a
# 8      verse592     3a        3             0      2.0                3a
# 9      verse617     3b        3             3      2.0                2b
# 10     verse701      0        0             0      2.0                 0
# 11     verse145      0        0             0      2.0                2a
# ...

# %%
df = df.head(17)

# %%
# display some statistics based on incorrect column
df['incorrect'].describe()
# Out:
# count    15.000000
# mean      1.066667
# std       1.032796
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.500000
# max       3.000000
# Name: incorrect, dtype: float64

# %%
df
# Out:
#    subject_name actual actual_R actual_flip_R  correct pred.experiment_5  \
# 0      verse542     2b        2             2      0.0                2a
# 1      verse015     2a        0             2      0.0                 0
# 2      verse526     3b        3             3      0.0                3a
# 3      verse607     2a        0             2      1.0                 0
# 4      verse085     3a        3             0      1.0                3a
# 5      verse594     3b        3             3      1.0                 0
# 6      verse765      0        0             0      1.0                 0
# 7      verse540     2a        2             0      2.0                2a
# 8      verse592     3a        3             0      2.0                3a
# 9      verse617     3b        3             3      2.0                2b
# 10     verse701      0        0             0      2.0                 0
# 11     verse145      0        0             0      2.0                2a
# ...

# %%
# drop all columns contains f1_score as substring
df = df[df.columns.drop(list(df.filter(regex='f1_score')))]

# %%
df
# Out:
#    subject_name actual actual_R actual_flip_R  correct pred.experiment_5  \
# 0      verse542     2b        2             2      0.0                2a
# 1      verse015     2a        0             2      0.0                 0
# 2      verse526     3b        3             3      0.0                3a
# 3      verse607     2a        0             2      1.0                 0
# 4      verse085     3a        3             0      1.0                3a
# 5      verse594     3b        3             3      1.0                 0
# 6      verse765      0        0             0      1.0                 0
# 7      verse540     2a        2             0      2.0                2a
# 8      verse592     3a        3             0      2.0                3a
# 9      verse617     3b        3             3      2.0                2b
# 10     verse701      0        0             0      2.0                 0
# 11     verse145      0        0             0      2.0                2a
# ...

# %%
# drop correct column
df = df.drop(['correct'], axis=1)

# %%
df
# Out:
#    subject_name actual actual_R actual_flip_R pred.experiment_5  \
# 0      verse542     2b        2             2                2a
# 1      verse015     2a        0             2                 0
# 2      verse526     3b        3             3                3a
# 3      verse607     2a        0             2                 0
# 4      verse085     3a        3             0                3a
# 5      verse594     3b        3             3                 0
# 6      verse765      0        0             0                 0
# 7      verse540     2a        2             0                2a
# 8      verse592     3a        3             0                3a
# 9      verse617     3b        3             3                2b
# 10     verse701      0        0             0                 0
# 11     verse145      0        0             0                2a
# 12     verse759      0        0             0                 0
# 13     verse046      0        0             0                 0
# ...

# %%
df.columns
# Out:
# Index(['subject_name', 'actual', 'actual_R', 'actual_flip_R',
#        'pred.experiment_5', 'pred.experiment_9', 'pred.experiment_10',
#        'pred_R.experiment_5', 'pred_R.experiment_9', 'pred_R.experiment_10',
#        'pred_flip_R.experiment_5', 'pred_flip_R.experiment_9',
#        'pred_flip_R.experiment_10', 'incorrect'],
#       dtype='object')
